# %%
import pandas as pd
df = pd.read_csv("sales_data.csv",encoding="latin1")
df.head()
# Out:
#           Category          City        Country  Customer Name  Manufacturer  \
# 0  Office Supplies       Houston  United States  Darren Powers  Message Book
# 1  Office Supplies    Naperville  United States  Phillina Ober         Avery
# 2  Office Supplies    Naperville  United States  Phillina Ober         SAFCO
# 3  Office Supplies    Naperville  United States  Phillina Ober           GBC
# 4  Office Supplies  Philadelphia  United States     Mick Brown         Avery
#
#    Order Date        Order ID  Postal Code  \
# 0  03-01-2013  CA-2011-103800        77095
# 1  04-01-2013  CA-2011-112326        60540
# 2  04-01-2013  CA-2011-112326        60540
# 3  04-01-2013  CA-2011-112326        60540
# 4  05-01-2013  CA-2011-141817        19143
#
#                                         Product Name   Region  ...  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  Central  ...
# 1                                          Avery 508  Central  ...
# 2                      SAFCO Boltless Steel Shelving  Central  ...
# 3         GBC Standard Plastic Binding Systems Combs  Central  ...
# 4  Avery Hi-Liter EverBold Pen Style Fluorescent ...     East  ...
#
#     Ship Date       Ship Mode         State Sub-Category Discount  \
# 0  07-01-2013  Standard Class         Texas        Paper      20%
# 1  08-01-2013  Standard Class      Illinois       Labels      20%
# 2  08-01-2013  Standard Class      Illinois      Storage      20%
# 3  08-01-2013  Standard Class      Illinois      Binders      80%
# 4  12-01-2013  Standard Class  Pennsylvania          Art      20%
#
#   Number of Records  Profit Profit Ratio Quantity  Sales
# 0                 1      $6          34%        2    $16
# 1                 1      $4          36%        3    $12
# 2                 1    -$65         -24%        3   $273
# 3                 1     -$5        -155%        2     $4
# 4                 1      $5          25%        3    $20
#
# [5 rows x 21 columns]

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'sales_data.csv']

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer Name', 'Manufacturer',
#        'Order Date', 'Order ID', 'Postal Code', 'Product Name', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State', 'Sub-Category',
#        'Discount', 'Number of Records', 'Profit', 'Profit Ratio', 'Quantity',
#        'Sales'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Category           9994 non-null   object
#  1   City               9994 non-null   object
#  2   Country            9994 non-null   object
#  3   Customer Name      9994 non-null   object
#  4   Manufacturer       9994 non-null   object
#  5   Order Date         9994 non-null   object
#  6   Order ID           9994 non-null   object
#  7   Postal Code        9994 non-null   int64
#  8   Product Name       9994 non-null   object
#  9   Region             9994 non-null   object
#  10  Segment            9994 non-null   object
#  11  Ship Date          9994 non-null   object
#  12  Ship Mode          9994 non-null   object
#  13  State              9994 non-null   object
#  14  Sub-Category       9994 non-null   object
#  15  Discount           9994 non-null   object
#  16  Number of Records  9994 non-null   int64
#  17  Profit             9994 non-null   object
#  18  Profit Ratio       9994 non-null   object
#  19  Quantity           9994 non-null   int64
#  20  Sales              9994 non-null   object
# dtypes: int64(3), object(18)
# memory usage: 1.6+ MB

# %%
df.isnull().sum()
# Out:
# Category             0
# City                 0
# Country              0
# Customer Name        0
# Manufacturer         0
# Order Date           0
# Order ID             0
# Postal Code          0
# Product Name         0
# Region               0
# Segment              0
# Ship Date            0
# Ship Mode            0
# State                0
# Sub-Category         0
# Discount             0
# Number of Records    0
# Profit               0
# Profit Ratio         0
# Quantity             0
# Sales                0
# dtype: int64

# %%
df.describe()
# Out:
#         Postal Code  Number of Records     Quantity
# count   9994.000000             9994.0  9994.000000
# mean   55190.379428                1.0     3.789574
# std    32063.693350                0.0     2.225110
# min     1040.000000                1.0     1.000000
Dual Perf Computer Printout Paper, 2700 Sheets, 1 Part, Heavyweight, 20 lbs., 14 7/8 x 11                            $98$123$33$369$123$164
# Cisco IP Phone 7961G VoIP phone - Dark gray                                                                                          $979$272$136
# Name: Sales, dtype: object

# %%
 df["Sales"]=pd.to_numeric(df["Sales"],errors="coerce")

# %%
top_products = df.groupby("Product Name")["Sales"].sum().sort_values(ascending=False).head(10)

# %%
top_products
# Out:
# Product Name
# "While you Were Out" Message Book, One Form per Page     0.0
# Panasonic KX-TG9471B                                     0.0
# Panasonic KX TS3282W Corded phone                        0.0
# Panasonic KX TS3282B Corded phone                        0.0
# Panasonic KX TS208W Corded phone                         0.0
# Panasonic KX T7736-B Digital phone                       0.0
# Panasonic KX T7731-B Digital phone                       0.0
# Panasonic KX MC6040 Color Laser Multifunction Printer    0.0
# Panasonic KX MB2061 Multifunction Printer                0.0
# Panasonic KX - TS880B Telephone                          0.0
# Name: Sales, dtype: float64

# %%
df["Sales"].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Sales, dtype: float64

# %%
df = pd.read_csv("sales_data.csv",encoding="latin1")

# %%
df["Sales"].head()
# Out:
# 0     $16
# 1     $12
# 2    $273
# 3      $4
# 4     $20
# Name: Sales, dtype: object

# %%
df["Sales"] = df["Sales"].replace('[\$,]', '', regex=True).astype(float)

# %%
df["Sales"].head()
# Out:
# 0     16.0
# 1     12.0
# 2    273.0
# 3      4.0
# 4     20.0
# Name: Sales, dtype: float64

# %%
top_products = df.groupby("Product Name")["Sales"].sum().sort_values(ascending=False).head(10)

top_products
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61600.0
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27454.0
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.0
# HON 5400 Series Task Chairs for Big and Tall                                   21870.0
# GBC DocuBind TL300 Electric Binding System                                     19824.0
# GBC Ibimaster 500 Manual ProClick Binding System                               19026.0
# Hewlett Packard LaserJet 3310 Copier                                           18840.0
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18375.0
# GBC DocuBind P400 Electric Binding System                                      17965.0
# High Speed Automatic Electric Letter Opener                                    17031.0
# Name: Sales, dtype: float64

# %%
import matplotlib.pyplot as plt

top_products.plot(kind="bar")

plt.title("Top 10 Products by Sales")
plt.xlabel("Product Name")
plt.ylabel("Total Sales")

plt.show()

# %%
df.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer Name', 'Manufacturer',
#        'Order Date', 'Order ID', 'Postal Code', 'Product Name', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State', 'Sub-Category',
#        'Discount', 'Number of Records', 'Profit', 'Profit Ratio', 'Quantity',
#        'Sales'],
#       dtype='object')

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"], dayfirst=True)

# %%
df["Month"] = df["Order Date"].dt.month

# %%
monthly_sales = df.groupby("Month")["Sales"].sum()

monthly_sales
# Out:
# Month
# 1      95666.0
# 2      59646.0
# 3     204487.0
# 4     138273.0
# 5     154740.0
# 6     151818.0
# 7     146421.0
# 8     161207.0
# 9     307187.0
# 10    197108.0
# 11    355262.0
# 12    325539.0
# Name: Sales, dtype: float64

# %%
import matplotlib.pyplot as plt

monthly_sales.plot(kind="line", marker="o")

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")

plt.show()

# %%
category_sales = df.groupby("Category")["Sales"].sum()

category_sales
# Out:
# Category
# Furniture          742006.0
# Office Supplies    719127.0
# Technology         836221.0
# Name: Sales, dtype: float64

# %%
import matplotlib.pyplot as plt

category_sales.plot(kind="bar")

plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")

plt.show()

# %%
region_sales = df.groupby("Region")["Sales"].sum()

region_sales
# Out:
# Region
# Central    501256.0
# East       678834.0
# South      391750.0
# West       725514.0
# Name: Sales, dtype: float64

# %%
region_sales.plot(kind="bar")

plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")

plt.show()
